# %% [markdown]
# # Object Oriented Programming

# %%
class User:
    def __init__(self):
        self.nickname = 'sampleNickname'
        self.city = 'sampleCity'
        
    def introduce(self):
        print('Hello, I am', self.nickname, 'and I live in', self.city)
        
sample_user = User()
sample_user.introduce() # to call a method on the object
# Out:
# Hello, I am sampleNickname and I live in sampleCity

# %%
print(sample_user.nickname)
print(sample_user.city)
# Out:
# sampleNickname
# sampleCity

# %% [markdown]
# Creating a new version of this class

# %%
class User:
    def __init__(self, nickname, city):
        self.nickname = nickname
        self.city = city
        
    def introduce(self):
        print('Hello, I am', self.nickname, 'and I live in', self.city)

# %%
first_user = User('Mary', 'NY')
second_user = User('John', 'London')
third_user = User('Rosie', 'Tokyo')

# %%
first_user.introduce()
second_user.introduce()
third_user.introduce()
# Out:
# Hello, I am Mary and I live in NY
# Hello, I am John and I live in London
# Hello, I am Rosie and I live in Tokyo

# %% [markdown]
# ## Encapsulation and Abstraction

# %%
class Car:
    def __init__(self, model, color, initial_speed = 0):
        self.model = model
        self.color = color
        if initial_speed < 0:
            self.__speed = 0
        else:
            self.__speed = initial_speed
        
    def speed_up(self):
        self.__speed += 5
    
    def slow_down(self):
        if self.__speed < 5:
            self.__speed = 0
        else:
            self.__speed -= 5
        
    def show_speed(self):
        print('Current speed:', self.__speed)

# %%
my_lovely_car = Car('T Roc', 'red')
my_lovely_car.speed_up()
my_lovely_car.speed_up()
my_lovely_car.show_speed()
# Out:
# Current speed: 10

# %%
my_lovely_car = Car('T Roc', 'red')
my_lovely_car.slow_down()
my_lovely_car.slow_down()
my_lovely_car.show_speed()
# Out:
# Current speed: 0

# %%
my_lovely_car2 = Car('Celta', 'blue', -50)
my_lovely_car2.show_speed()
# Out:
# Current speed: 0

# %% [markdown]
# When adding two underscores to a property, in example "speed", it stops the user from changing the property directly. It makes it a private property. So even if you do an operation like this -> my_lovely_car3.speed = -10, it won't change the property. >> *ENCAPSULATION*
#
# __speed

# %%
my_lovely_car3 = Car('Celta', 'blue', -50)
my_lovely_car3.speed = -10
my_lovely_car3.show_speed()
# Out:
# Current speed: 0

# %% [markdown]
# *ABSTRACTION* - Objects should keep the details of how they work to themselves.

# %% [markdown]
# ## Instance Variables

# %%
class Dog():
    def __init__(self, name, age):
        self.name = name
        self.age = age

# %%
my_pet = Dog('Teddy', 2)
my_pet.__dict__
# Out:
# {'name': 'Teddy', 'age': 2}

# %%
my_pet.color = 'brown'
my_pet.__dict__
# Out:
# {'name': 'Teddy', 'age': 2, 'color': 'brown'}

# %%
del my_pet.name
my_pet.__dict__
# Out:
# {'age': 2, 'color': 'brown'}

# %%
class Dog():
    def __init__(self, name, age):
        self.__name = name
        self.age = age

# %%
my_pet = Dog('Teddy', 2)
print(my_pet.__dict__)
print(my_pet.__name)
# Out:
# {'_Dog__name': 'Teddy', 'age': 2}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14304/4105592290.py in <module>
#       1 my_pet = Dog('Teddy', 2)
#       2 print(my_pet.__dict__)
# ----> 3 print(my_pet.__name)
#
# AttributeError: 'Dog' object has no attribute '__name'

# %%
# Name mangling -> _Dog__name

# %%
my_pet = Dog('Teddy', 2)
print(my_pet.__dict__)
print(my_pet._Dog__name)
# Out:
# {'_Dog__name': 'Teddy', 'age': 2}
# Teddy

# %%
# Someone can still access the private property outside the class if they want to.

# %% [markdown]
# ## Class Variables

# %% [markdown]
# Property that exists in just one copy, stored in the class itself. It exists even if you dont create any object in that class.

# %%
class Dog():
    counter = 0
    def __init__(self, name, age):
        self.__name = name
        self.age = age
        Dog.counter += 1

my_pet = Dog('Teddy', 2)
kates_pet = Dog('Foxy', 5)
adams_pet = Dog('Luna', 1)

print(my_pet.counter)
print(kates_pet.counter)
print(adams_pet.counter)
# Out:
# 3
# 3
# 3

# %%
my_pet.__dict__
# Out:
# {'_Dog__name': 'Teddy', 'age': 2}

# %%
print(Dog.counter)
# Out:
# 3

# %%
class Dog():
    __counter = 0
    def __init__(self, name, age):
        self.__name = name
        self.age = age
        Dog.__counter += 1

# %%
print(Dog._Dog__counter)
# Out:
# 0

# %%
class Dog():
    counter = 0
    def __init__(self, name, age):
        self.__name = name
        self.age = age
        Dog.counter += 1

my_pet = Dog('Tom', 5)

if hasattr(my_pet, 'name'):
    print('My pet is called', my_pet.name)
else:
    print('My per has no name')
# Out:
# My per has no name

# %%
# It shows my pet has no name because "name" is private property -> __name

# %%
class Dog():
    counter = 0
    def __init__(self, name, age):
        self.name = name
        self.age = age
        Dog.counter += 1

my_pet = Dog('Tom', 5)

if hasattr(my_pet, 'name'):
    print('My pet is called', my_pet.name)
else:
    print('My per has no name')
# Out:
# My pet is called Tom

# %%
# It shows my pet is called Tom because "name" is public property -> name

# %% [markdown]
# ## Exercise - Deck of Cards

# %% [markdown]
# There are many card games that you could implement in Python: poker, war, blackjack... Naturally, implementing an entire card game is a long and complicated process. In this exercise, we're only going to focus on a tiny part that could be used in many card games: implementing a deck of cards using OOP with some basic, ready-to-use operations.
#
# Your task is to implement two classes: Card and Deck. The Deck should be a standard 52-card deck as described here: wiki page.
#
# The Card should be a very simple class with just two attributes: suit and value. It should also have a method named present() that returns a string showing {value} of {suit}. For instance, for a card created in the following way Card('hearts', '10') the method should return  10 of hearts.
#
# The Deck should have one attribute: cards. It should be a list of Card objects representing a full card deck with all combinations of suits and values. For your convenience, here are the exact values that should be used:
#
# suits = ['hearts', 'diamonds', 'clubs', 'spades']
# values = ['Ace', '2', '3', '4', '5', '6', '7', '8', '9', '10', 'Jack', 'Queen', 'King']
# In other words, the Deck should internally have a cards list with card objects such as Card('hearts', 'Ace') or Card('spades', '5'). When created, each object of the Deck class should have exactly 52 cards, one of each value and suit.
#
# The Deck class should also make available the following methods:
#
# 1. shuffle(): this method should randomly change the order of cards in the deck*
#
# 2.  deal(): this method should return one card object from the Deck (the currently last card in the cards list) and then also remove that object from the Deck. If there are no cards left, return None.
#
# 3. count_remaining(): this method should return the number of cards (an integer) in the deck
#
# 4. get_remaining(): this method should return a list of strings, each string describing a single remaining card, using the present() method for the Card class described above. For instance, if there are two cards remaining in the deck, the returned list could look as follows (the remaining cards shown below are picked at random):
#
# ['3 of hearts', 'Jack of spades']
# * You can use the shuffle method from the random module like this: random.shuffle(list_name)

# %%
from random import shuffle
 
class Card:
	def __init__(self, suit, value):
		self.suit = suit
		self.value = value
 
	def present(self):
		return self.value + ' of ' + self.suit 
 
class Deck:
	def __init__(self):
	    suits = ['hearts', 'diamonds', 'clubs', 'spades']
	    values = ['Ace', '2', '3', '4', '5', '6', '7', '8', '9', '10', 'Jack', 'Queen', 'King']
	    self.cards = [Card(suit, value) for suit in suits for value in values]
 
	def shuffle(self):
		shuffle(self.cards)
 
	def deal(self):
	    if len(self.cards) == 0:
	        return None
	    return self.cards.pop()
 
	def count_remaining(self):
	    return len(self.cards)
	
	def get_remaining(self):
	    return [x.present() for x in self.cards]

# %% [markdown]
# ## Inheritance

# %%
class Vehicle:
    pass

# %%
class LandVehicle(Vehicle):
    pass

# %%
class Car(LandVehicle):
    pass

# %% [markdown]
# Car is a subclass of LandVehicle and Vehicle.
# LandVehicle is a subclass of Vehicle.

# %%
issubclass(LandVehicle, Vehicle)
# Out:
# True

# %%
issubclass(Car, LandVehicle)
# Out:
# True

# %%
my_car = Car()
print(my_car.__dict__)
# Out:
# {}

# %%
class Vehicle:
    def __init__(self, speed):
        self.speed = speed

class LandVehicle(Vehicle):
    pass

class Car(LandVehicle):
    pass

# %%
my_car = Car()
print(my_car.__dict__)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10272/334537133.py in <module>
# ----> 1 my_car = Car()
#       2 print(my_car.__dict__)
#
# TypeError: __init__() missing 1 required positional argument: 'speed'

# %%
my_car = Car(5)
print(my_car.__dict__)
# Out:
# {'speed': 5}

# %% [markdown]
# This happens because Car inherts the properties of its superclasses.

# %%
class Vehicle:
    def __init__(self, speed):
        self.speed = speed

class LandVehicle(Vehicle):
    def __init__(self, wheel_count):
        self.wheel_count = wheel_count

class Car(LandVehicle):
    pass

# %%
my_car = Car(5)
print(my_car.__dict__)
# Out:
# {'wheel_count': 5}

# %% [markdown]
# This happens because Car inherits the properties of the superclass that has one. In the first example, LandVehicle didn't have any, so it inhertied the property of Vehicle. Now it inherits the properties of LandVehicle.

# %%
class Vehicle:
    def __init__(self, speed):
        self.speed = speed

class LandVehicle(Vehicle):
    def __init__(self, speed, wheel_count):
        Vehicle.__init__(self,speed) # add this piece for Car to inherit both
        self.wheel_count = wheel_count

class Car(LandVehicle):
    pass

# %%
my_car = Car(5,10)
print(my_car.__dict__)
# Out:
# {'speed': 5, 'wheel_count': 10}

# %%
# Using SUPER keyword (dont need to provide the self parameter in this case)

# %%
class Vehicle:
    def __init__(self, speed):
        self.speed = speed

class LandVehicle(Vehicle):
    def __init__(self, speed, wheel_count):
        super().__init__(speed) # add this piece for Car to inherit both
        self.wheel_count = wheel_count

class Car(LandVehicle):
    pass

# %%
my_car = Car(5,10)
print(my_car.__dict__)
# Out:
# {'speed': 5, 'wheel_count': 10}

# %% [markdown]
# Inheriting class methods and variables

# %%
class Vehicle:
    class_message = 'This is a message from the Vehicle class!'
    def __init__(self, speed):
        self.speed = speed

class LandVehicle(Vehicle):
    def __init__(self, speed, wheel_count):
        super().__init__(speed) # add this piece for Car to inherit both
        self.wheel_count = wheel_count
        print(Vehicle.class_message)

class Car(LandVehicle):
    pass

# %%
my_car = Car(50,4)
# Out:
# This is a message from the Vehicle class!

# %%
class Vehicle:
    class_message = 'This is a message from the Vehicle class!'
    def __init__(self, speed):
        self.speed = speed

class LandVehicle(Vehicle):
    def __init__(self, speed, wheel_count):
        super().__init__(speed) # add this piece for Car to inherit both
        self.wheel_count = wheel_count
        print(super().class_message)

class Car(LandVehicle):
    pass

# %%
my_car = Car(50,4)
# Out:
# This is a message from the Vehicle class!

# %%
my_car.class_message
# Out:
# 'This is a message from the Vehicle class!'

# %%
class Vehicle:
    class_message = 'This is a message from the Vehicle class!'
    def __init__(self, speed):
        self.speed = speed

class LandVehicle(Vehicle):
    def __init__(self, speed, wheel_count):
        super().__init__(speed) # add this piece for Car to inherit both
        self.wheel_count = wheel_count
        print(super().class_message)
        
    def speed_up(self):
        self.speed +=5

class Car(LandVehicle):
    def super_speed(self):
        print('Super speed activated')
        super().speed_up()
        super().speed_up()
        super().speed_up()

# %%
my_fast_car = Car(10,4)
print(my_fast_car.__dict__)

my_fast_car.super_speed()
print(my_fast_car.__dict__)
# Out:
# This is a message from the Vehicle class!
# {'speed': 10, 'wheel_count': 4}
# Super speed activated
# {'speed': 25, 'wheel_count': 4}

# %%
class Animal():
    def __init__(self):
        self.species = 'general'
    
    def produce_sound(self):
        print('General animal sound')

class Dog(Animal):
    pass

my_pet = Dog()
print(my_pet.species)
my_pet.produce_sound()
# Out:
# general
# General animal sound

# %%
class Animal():
    def __init__(self):
        self.species = 'general'
    
    def produce_sound(self):
        print('General animal sound')

class Dog(Animal):
    def __init__(self):
        self.species = 'Canis familiaris'
        
    def produce_sound(self):
        print('woof woof')
        
my_pet = Dog()
print(my_pet.species)
my_pet.produce_sound()
# Out:
# Canis familiaris
# woof woof

# %% [markdown]
# Python will first try to find the entity inside the object, if it fails it tries to find it in all the classes from bottom to top.

# %%
my_first_pet = Animal()
my_second_pet = Dog()

my_first_pet.produce_sound()
my_second_pet.produce_sound()
# Out:
# General animal sound
# woof woof

# %%
class Animal():
    def __init__(self):
        self.species = 'general'
    
    def produce_sound(self):
        print('General animal sound')
        
    def present(self):
        print('I can do the following sound:')
        self.produce_sound()

class Dog(Animal):
    def __init__(self):
        self.species = 'Canis familiaris'
        
    def produce_sound(self):
        print('woof woof')

# %%
my_first_pet = Animal()
my_second_pet = Dog()

my_first_pet.present()
my_second_pet.present()
# Out:
# I can do the following sound:
# General animal sound
# I can do the following sound:
# woof woof

# %%
# isintance()

# %%
class Vehicle:
    def __init__(self, speed):
        self.speed = speed

class LandVehicle(Vehicle):
    def __init__(self, speed, wheel_count):
        super().__init__(speed) # add this piece for Car to inherit both
        self.wheel_count = wheel_count

class Car(LandVehicle):
    pass

# %%
my_vehicle = Vehicle(50)
my_land_vehicle = LandVehicle(50,4)
my_car = Car(60,4)

# %%
print(isinstance(my_vehicle, Vehicle))
print(isinstance(my_land_vehicle, Vehicle))
print(isinstance(my_car, Vehicle))
# Out:
# True
# True
# True

# %%
print(isinstance(my_vehicle, LandVehicle))
print(isinstance(my_land_vehicle, LandVehicle))
print(isinstance(my_car, LandVehicle))
# Out:
# False
# True
# True

# %%
print(isinstance(my_vehicle, Car))
print(isinstance(my_land_vehicle, Car))
print(isinstance(my_car, Car))
# Out:
# False
# False
# True

# %%
# MULTIPLE INHERITANCE

# %%
class Vehicle():
    pass

class Flyable():
    pass

class Airplane(Vehicle, Flyable): # this class inherits from Vehicle and Flyable
    pass

# %%
my_plane = Airplane()

# %%
class Vehicle():
    def go(self):
        print('Going!')

class Flyable():
    def fly(self):
        print('Flying!')

class Airplane(Vehicle, Flyable): # this class inherits from Vehicle and Flyable
    pass

# %%
my_plane = Airplane()
my_plane.go()
my_plane.fly()
# Out:
# Going!
# Flying!

# %%
class Vehicle():
    def go(self):
        print('Going!')
        
    def introduce(self):
        print('Im a vehicle.')

class Flyable():
    def fly(self):
        print('Flying!')
        
    def introduce(self):
        print('Im a flyable.')

class Airplane(Vehicle, Flyable): # this class inherits from Vehicle and Flyable
    pass

# %%
my_plane = Airplane()
my_plane.introduce()
# Out:
# Im a vehicle.

# %% [markdown]
# MRO - Method Resolution Order - in Python, it looks for a method in the specified name:
# 1. Inside the object
# 2. Look in the superclasses from left to right
# 3. Show an error

# %%
class Vehicle():
    def go(self):
        print('Going!')
        
    def introduce(self):
        print('Im a vehicle.')

class Flyable():
    def fly(self):
        print('Flying!')
        
    def introduce(self):
        print('Im a flyable.')

class Airplane(Flyable,Vehicle): # this class inherits from Flyable and Vehicle
    pass

# %%
my_plane = Airplane()
my_plane.introduce()
# Out:
# Im a flyable.

# %%
# This happens because FLYABLE is now the first superclass 
# defined in front of the Vehicle in "class Airplane(Flyable,Vehicle)"

# %%
class Vehicle():
    def go(self):
        print('Going!')
        
    def introduce(self):
        print('Im a vehicle.')

class Flyable():
    def fly(self):
        print('Flying!')
        
    def introduce(self):
        print('Im a flyable.')

class Airplane(Flyable,Vehicle): # this class inherits from Flyable and Vehicle
    def introduce(self):
        print('Im an airplane')

# %%
my_plane = Airplane()
my_plane.introduce()
# Out:
# Im an airplane

# %%
# It uses it's own version, because it looks inside the object.
